# %% [markdown]
# Contains the following columns:
# - **date** - recorded date of measurement - (**int**)
# - **cloud_cover** - cloud cover measurement in oktas - (**float**)
# - **sunshine** - sunshine measurement in hours (hrs) - (**float**)
# - **global_radiation** - irradiance measurement in Watt per square meter (W/m2) - (**float**)
# - **max_temp** - maximum temperature recorded in degrees Celsius (°C) - (**float**)
# - **mean_temp** - **target** mean temperature in degrees Celsius (°C) - (**float**)
# - **min_temp** - minimum temperature recorded in degrees Celsius (°C) - (**float**)
# - **precipitation** - precipitation measurement in millimeters (mm) - (**float**)
# - **pressure** - pressure measurement in Pascals (Pa) - (**float**)
# - **snow_depth** - snow depth measurement in centimeters (cm) - (**float**)

# %%
# Run this cell to install mlflow
# !pip install mlflow
# Out:
# Requirement already satisfied: mlflow in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (2.13.0)
# Requirement already satisfied: Flask<4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: entrypoints<1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (0.4)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.1.43)
# Requirement already satisfied: graphene<4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.6)
# Requirement already satisfied: matplotlib<4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.8.4)
# Requirement already satisfied: numpy<2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: opentelemetry-api<3,>=1.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.24.0)
# Requirement already satisfied: packaging<25 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (24.0)
# Requirement already satisfied: pandas<3 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (4.25.3)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (15.0.2)
# Requirement already satisfied: pytz<2025 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (2024.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: querystring-parser<2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.5.0)
# Requirement already satisfied: scipy<2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (2.0.30)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (0.5.0)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: waitress<4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: Mako in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.11.0)
# Requirement already satisfied: colorama in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from click<9,>=7.0->mlflow) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\users\hbz\appdata\roaming\python\python312\site-packages (from docker<8,>=4.0.0->mlflow) (306)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.2.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from Flask<4->mlflow) (1.8.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from gitpython<4,>=3.1.9->mlflow) (4.0.11)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: aniso8601<10,>=8 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.19.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api<3,>=1.0.0->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-sdk<3,>=1.0.0->mlflow) (0.45b0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: six in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.0.0->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hbz\appdata\local\programs\python\python312\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow) (5.0.1)

# %%
# Run this cell to import the modules you require
import pandas as pd
import numpy as np
import mlflow
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Read in the data
weather = pd.read_csv("london_weather.csv")

# %%
weather.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  19790101          2.0       7.0              52.0       2.3       -4.1
# 1  19790102          6.0       1.7              27.0       1.6       -2.6
# 2  19790103          5.0       0.0              13.0       1.3       -2.8
# 3  19790104          8.0       0.0              13.0      -0.3       -2.6
# 4  19790105          6.0       2.0              29.0       5.6       -0.8
#
#    min_temp  precipitation  pressure  snow_depth
# 0      -7.5            0.4  101900.0         9.0
# 1      -7.5            0.0  102530.0         8.0
# 2      -7.2            0.0  102050.0         4.0
# 3      -6.5            0.0  100840.0         2.0
# 4      -1.4            0.0  102250.0         1.0

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15341 entries, 0 to 15340
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              15341 non-null  int64
#  1   cloud_cover       15322 non-null  float64
#  2   sunshine          15341 non-null  float64
#  3   global_radiation  15322 non-null  float64
#  4   max_temp          15335 non-null  float64
#  5   mean_temp         15305 non-null  float64
#  6   min_temp          15339 non-null  float64
#  7   precipitation     15335 non-null  float64
#  8   pressure          15337 non-null  float64
#  9   snow_depth        13900 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 1.2 MB

# %%
# Correct type has to be chosen for the date column
weather['date'] = pd.to_datetime(weather['date'], format='%Y%m%d')

# %%
weather['month'] = weather['date'].dt.month
weather['year'] = weather['date'].dt.year
weather
# Out:
#             date  cloud_cover  sunshine  global_radiation  max_temp  \
# 0     1979-01-01          2.0       7.0              52.0       2.3
# 1     1979-01-02          6.0       1.7              27.0       1.6
# 2     1979-01-03          5.0       0.0              13.0       1.3
# 3     1979-01-04          8.0       0.0              13.0      -0.3
# 4     1979-01-05          6.0       2.0              29.0       5.6
# ...          ...          ...       ...               ...       ...
# 15336 2020-12-27          1.0       0.9              32.0       7.5
# 15337 2020-12-28          7.0       3.7              38.0       3.6
# 15338 2020-12-29          7.0       0.0              21.0       4.1
# 15339 2020-12-30          6.0       0.4              22.0       5.6
# 15340 2020-12-31          7.0       1.3              34.0       1.5
#
#        mean_temp  min_temp  precipitation  pressure  snow_depth  month  year
# 0           -4.1      -7.5            0.4  101900.0         9.0      1  1979
# 1           -2.6      -7.5            0.0  102530.0         8.0      1  1979
# 2           -2.8      -7.2            0.0  102050.0         4.0      1  1979
# 3           -2.6      -6.5            0.0  100840.0         2.0      1  1979
# 4           -0.8      -1.4            0.0  102250.0         1.0      1  1979
# ...          ...       ...            ...       ...         ...    ...   ...
# 15336        7.5       7.6            2.0   98000.0         NaN     12  2020
# 15337        1.1      -1.3            0.2   97370.0         NaN     12  2020
# 15338        2.6       1.1            0.0   98830.0         NaN     12  2020
# 15339        2.7      -0.1            0.0  100200.0         NaN     12  2020
# 15340       -0.8      -3.1            0.0  100500.0         NaN     12  2020
#
# [15341 rows x 12 columns]

# %%
sns.lineplot(data=weather, x='year', y='mean_temp')
plt.show()

# %%
sns.heatmap(weather.corr(), annot=True, cmap='coolwarm', fmt='.2f',linewidths=0.5,linecolor='black')
plt.show()

# %%
# Choose features, define the target, and drop null values
feature_selection = ['month', 'cloud_cover', 'sunshine', 'precipitation', 'pressure', 'global_radiation']
target_var = 'mean_temp'
weather = weather.dropna(subset=['mean_temp'])
# Subset feature and target sets
X = weather[feature_selection]    
y = weather[target_var]
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
    
# Impute missing values
imputer = SimpleImputer(strategy="mean")
# Fit on the training data
X_train = imputer.fit_transform(X_train)
# Transform on the test data
X_test  = imputer.transform(X_test)
# Scale the data
scaler = StandardScaler()
# Fit on the training data
X_train = scaler.fit_transform(X_train)
# Transform on the test data
X_test = scaler.transform(X_test)

# %%
# Predict, evaluate and log the parameters and metrics of your models
for idx, depth in enumerate([1,2,5,10,20]):
    run_name = f"run_{idx}"
    with mlflow.start_run(run_name=run_name):
        # Create models
        lin_reg = LinearRegression().fit(X_train, y_train)
        tree_reg = DecisionTreeRegressor(random_state=42,max_depth=depth).fit(X_train, y_train)
        forest_reg =  RandomForestRegressor(random_state=42,max_depth=depth).fit(X_train, y_train)

        # Log models
        mlflow.sklearn.log_model(lin_reg,"lin_reg")
        mlflow.sklearn.log_model(tree_reg, "tree_reg")
        mlflow.sklearn.log_model(forest_reg,"forest_reg")

        # Evaluate performance
        y_pred_lin_reg = lin_reg.predict(X_test)
        lin_reg_rmse = mean_squared_error(y_test, y_pred_lin_reg)
        y_pred_tree_reg = tree_reg.predict(X_test)
        tree_reg_rmse = mean_squared_error(y_test, y_pred_tree_reg)
        y_pred_forest_reg = forest_reg.predict(X_test)
        forest_reg_rmse = mean_squared_error(y_test, y_pred_forest_reg)
        # Log performance
        mlflow.log_param("max_depth", depth)
        mlflow.log_metric("rmse_lr",lin_reg_rmse)
        mlflow.log_metric("rmse_lr",tree_reg_rmse)
        mlflow.log_metric("rmse_lr",forest_reg_rmse)

# %%
# Search the runs for the experiment's results
experiment_results = mlflow.search_runs()
experiment_results
# Out:
#                              run_id experiment_id    status  \
# 0  67b46715bb4a42789f4ed11d56d70c41             0  FINISHED
# 1  f1b37779a62a444baa154de1f0f6ad82             0  FINISHED
# 2  2411b925fa0745ab8ecb118842398027             0  FINISHED
# 3  bba35edaf23f43a7a78c330c428d6a41             0  FINISHED
# 4  76e982e63e1141fcb05b0fd85c1d158d             0  FINISHED
#
#                                         artifact_uri  \
# 0  file:///c:/Users/hbz/Documents/workspace/datac...
# 1  file:///c:/Users/hbz/Documents/workspace/datac...
# 2  file:///c:/Users/hbz/Documents/workspace/datac...
# 3  file:///c:/Users/hbz/Documents/workspace/datac...
# 4  file:///c:/Users/hbz/Documents/workspace/datac...
#
#                         start_time                         end_time  \
# 0 2024-06-02 11:57:23.715000+00:00 2024-06-02 11:57:34.581000+00:00
# 1 2024-06-02 11:57:12.095000+00:00 2024-06-02 11:57:23.699000+00:00
# 2 2024-06-02 11:57:03.002000+00:00 2024-06-02 11:57:12.095000+00:00
# 3 2024-06-02 11:56:54.647000+00:00 2024-06-02 11:57:02.995000+00:00
# 4 2024-06-02 11:56:44.559000+00:00 2024-06-02 11:56:54.636000+00:00
#
#    metrics.rmse_lr params.max_depth  \
# 0        14.951931               20
# 1        14.951931               10
# 2        14.951931                5
# 3        14.685323                2
# 4        22.581836                1
#
#                        tags.mlflow.log-model.history tags.mlflow.source.type  \
# 0  [{"run_id": "67b46715bb4a42789f4ed11d56d70c41"...                   LOCAL
# 1  [{"run_id": "f1b37779a62a444baa154de1f0f6ad82"...                   LOCAL
# 2  [{"run_id": "2411b925fa0745ab8ecb118842398027"...                   LOCAL
# 3  [{"run_id": "bba35edaf23f43a7a78c330c428d6a41"...                   LOCAL
# 4  [{"run_id": "76e982e63e1141fcb05b0fd85c1d158d"...                   LOCAL
#
#   tags.mlflow.runName                            tags.mlflow.source.name  \
# 0               run_4  C:\Users\hbz\AppData\Roaming\Python\Python312\...
# 1               run_3  C:\Users\hbz\AppData\Roaming\Python\Python312\...
# 2               run_2  C:\Users\hbz\AppData\Roaming\Python\Python312\...
# 3               run_1  C:\Users\hbz\AppData\Roaming\Python\Python312\...
# 4               run_0  C:\Users\hbz\AppData\Roaming\Python\Python312\...
#
#   tags.mlflow.user
# 0              hbz
# 1              hbz
# 2              hbz
# 3              hbz
# 4              hbz
